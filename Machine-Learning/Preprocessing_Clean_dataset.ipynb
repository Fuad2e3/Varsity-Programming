# %% [markdown]
# <a href="https://colab.research.google.com/github/Fuad2e3/Maching-Learning/blob/main/Preprocessing_Clean_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab Report 1: Preprocessing
#
# Objective: Perform preprocessing on a Bangla SMS Spam Dataset.
#
# Dataset: https://raw.githubusercontent.com/Ataullha/Machine-Learning-Lab/refs/heads/main/bangla_spam.csv
#
# Steps: Data cleaning, punctuation removal, stopword removal, tokenization, stemming.
# Result: Clean dataset ready for training.
# Conclusion: Preprocessing improves model performance.

# %%
import numpy as np
import pandas as pd

# %%
Spam = pd.read_csv('/content/Data/bangla_spam.csv')

# %%
Spam.head()
# Out:
#    type                                               text
# 0  spam  এই মেসেজটি শেয়ার করুন এবং জিতে নিন আকর্ষণীয় ...
# 1  spam  আপনার বন্ধুদের রেফার করুন এবং প্রতি রেফারেলে ২...
# 2   ham  ট্রানজ্যাকশন নম্বর R234321.1554.640085 20 টাকা...
# 3  spam  নতুন অফার! সীমিত সময়ের জন্য পণ্যের উপর ৯০% পর...
# 4   ham  নববর্ষের শুভেচ্ছা!! আল্লাহ আপনার সকল কষ্ট দূর ...

# %% [markdown]
# # **Data Cleaning**

# %%
Spam.isnull().sum()
# Out:
# type    0
# text    0
# dtype: int64

# %%
Spam.duplicated().sum()
# Out:
# np.int64(25)

# %%
Spam = Spam.drop_duplicates()
Spam
# Out:
#       type                                               text
# 0     spam  এই মেসেজটি শেয়ার করুন এবং জিতে নিন আকর্ষণীয় ...
# 1     spam  আপনার বন্ধুদের রেফার করুন এবং প্রতি রেফারেলে ২...
# 2      ham  ট্রানজ্যাকশন নম্বর R234321.1554.640085 20 টাকা...
# 3     spam  নতুন অফার! সীমিত সময়ের জন্য পণ্যের উপর ৯০% পর...
# 4      ham  নববর্ষের শুভেচ্ছা!! আল্লাহ আপনার সকল কষ্ট দূর ...
# ...    ...                                                ...
# 2597  spam   প্রতিদিন ১০০ টাকা জিততে চান? এখনই অংশগ্রহণ করুন!
# 2598  spam  মোবাইল অ্যাপ ডাউনলোড করুন এবং ৫০০ টাকা বোনাস পান!
# 2599  spam    নতুন গ্রাহকদের জন্য বিশেষ অফার, আজই উপভোগ করুন!
# 2600  spam  আপনার অ্যাকাউন্ট আপগ্রেড করুন এবং এক্সক্লুসিভ ...
# 2601  spam  বিশেষ ছাড়! ২৪ ঘন্টার মধ্যে অর্ডার করুন এবং ৩০...
#
# [2577 rows x 2 columns]

# %% [markdown]
# # **Punctuation Removal**

# %%
Spam['text'] = Spam['text'].str.replace('[.,!?:;]', '')
Spam
# Out:
#       type                                               text
# 0     spam  এই মেসেজটি শেয়ার করুন এবং জিতে নিন আকর্ষণীয় ...
# 1     spam  আপনার বন্ধুদের রেফার করুন এবং প্রতি রেফারেলে ২...
# 2      ham  ট্রানজ্যাকশন নম্বর R234321.1554.640085 20 টাকা...
# 3     spam  নতুন অফার! সীমিত সময়ের জন্য পণ্যের উপর ৯০% পর...
# 4      ham  নববর্ষের শুভেচ্ছা!! আল্লাহ আপনার সকল কষ্ট দূর ...
# ...    ...                                                ...
# 2597  spam   প্রতিদিন ১০০ টাকা জিততে চান? এখনই অংশগ্রহণ করুন!
# 2598  spam  মোবাইল অ্যাপ ডাউনলোড করুন এবং ৫০০ টাকা বোনাস পান!
# 2599  spam    নতুন গ্রাহকদের জন্য বিশেষ অফার, আজই উপভোগ করুন!
# 2600  spam  আপনার অ্যাকাউন্ট আপগ্রেড করুন এবং এক্সক্লুসিভ ...
# 2601  spam  বিশেষ ছাড়! ২৪ ঘন্টার মধ্যে অর্ডার করুন এবং ৩০...
#
# [2577 rows x 2 columns]

# %% [markdown]
# # **Stopword Removal**

# %%
stopwords = ['আমি','তুমি','এই','ওই','সে','এটা']
pattern = '|'.join(stopwords)
Spam['text'] = Spam['text'].str.replace(pattern, '')
Spam
# Out:
#       type                                               text
# 0     spam  এই মেসেজটি শেয়ার করুন এবং জিতে নিন আকর্ষণীয় ...
# 1     spam  আপনার বন্ধুদের রেফার করুন এবং প্রতি রেফারেলে ২...
# 2      ham  ট্রানজ্যাকশন নম্বর R234321.1554.640085 20 টাকা...
# 3     spam  নতুন অফার! সীমিত সময়ের জন্য পণ্যের উপর ৯০% পর...
# 4      ham  নববর্ষের শুভেচ্ছা!! আল্লাহ আপনার সকল কষ্ট দূর ...
# ...    ...                                                ...
# 2597  spam   প্রতিদিন ১০০ টাকা জিততে চান? এখনই অংশগ্রহণ করুন!
# 2598  spam  মোবাইল অ্যাপ ডাউনলোড করুন এবং ৫০০ টাকা বোনাস পান!
# 2599  spam    নতুন গ্রাহকদের জন্য বিশেষ অফার, আজই উপভোগ করুন!
# 2600  spam  আপনার অ্যাকাউন্ট আপগ্রেড করুন এবং এক্সক্লুসিভ ...
# 2601  spam  বিশেষ ছাড়! ২৪ ঘন্টার মধ্যে অর্ডার করুন এবং ৩০...
#
# [2577 rows x 2 columns]

# %% [markdown]
# # **Tokenization**

# %%
Spam['tokens'] = Spam['text'].str.split()

Spam
# Out:
#       type                                               text  \
# 0     spam  এই মেসেজটি শেয়ার করুন এবং জিতে নিন আকর্ষণীয় ...
# 1     spam  আপনার বন্ধুদের রেফার করুন এবং প্রতি রেফারেলে ২...
# 2      ham  ট্রানজ্যাকশন নম্বর R234321.1554.640085 20 টাকা...
# 3     spam  নতুন অফার! সীমিত সময়ের জন্য পণ্যের উপর ৯০% পর...
# 4      ham  নববর্ষের শুভেচ্ছা!! আল্লাহ আপনার সকল কষ্ট দূর ...
# ...    ...                                                ...
# 2597  spam   প্রতিদিন ১০০ টাকা জিততে চান? এখনই অংশগ্রহণ করুন!
# 2598  spam  মোবাইল অ্যাপ ডাউনলোড করুন এবং ৫০০ টাকা বোনাস পান!
# 2599  spam    নতুন গ্রাহকদের জন্য বিশেষ অফার, আজই উপভোগ করুন!
# 2600  spam  আপনার অ্যাকাউন্ট আপগ্রেড করুন এবং এক্সক্লুসিভ ...
# 2601  spam  বিশেষ ছাড়! ২৪ ঘন্টার মধ্যে অর্ডার করুন এবং ৩০...
#
#                                                  tokens
# 0     [এই, মেসেজটি, শেয়ার, করুন, এবং, জিতে, নিন, আক...
# 1     [আপনার, বন্ধুদের, রেফার, করুন, এবং, প্রতি, রেফ...
# ...

# %% [markdown]
# # **Stemming**

# %%
Spam['text'] = Spam['text'].str[:-1]
Spam
# Out:
#       type                                               text  \
# 0     spam  এই মেসেজটি শেয়ার করুন এবং জিতে নিন আকর্ষণীয় ...
# 1     spam  আপনার বন্ধুদের রেফার করুন এবং প্রতি রেফারেলে ২...
# 2      ham  ট্রানজ্যাকশন নম্বর R234321.1554.640085 20 টাকা...
# 3     spam  নতুন অফার! সীমিত সময়ের জন্য পণ্যের উপর ৯০% পর...
# 4      ham  নববর্ষের শুভেচ্ছা!! আল্লাহ আপনার সকল কষ্ট দূর ...
# ...    ...                                                ...
# 2597  spam     প্রতিদিন ১০০ টাকা জিততে চান? এখনই অংশগ্রহণ করু
# 2598  spam    মোবাইল অ্যাপ ডাউনলোড করুন এবং ৫০০ টাকা বোনাস পা
# 2599  spam      নতুন গ্রাহকদের জন্য বিশেষ অফার, আজই উপভোগ করু
# 2600  spam  আপনার অ্যাকাউন্ট আপগ্রেড করুন এবং এক্সক্লুসিভ ...
# 2601  spam  বিশেষ ছাড়! ২৪ ঘন্টার মধ্যে অর্ডার করুন এবং ৩০...
#
#                                                  tokens
# 0     [এই, মেসেজটি, শেয়ার, করুন, এবং, জিতে, নিন, আক...
# 1     [আপনার, বন্ধুদের, রেফার, করুন, এবং, প্রতি, রেফ...
# ...
